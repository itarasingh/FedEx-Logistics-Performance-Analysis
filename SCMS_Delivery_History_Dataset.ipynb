# %% [markdown]
# <a href="https://colab.research.google.com/github/itarasingh/SCMS_Delivery_History_Dataset.csv/blob/main/SCMS_Delivery_History_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/itarasingh/SCMS_Delivery_History_Dataset.csv/refs/heads/main/SCMS_Delivery_History_Dataset.csv')

# %%
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# 1                        240               1000          6200.0       6.20
# 2                        100                500         40000.0      80.00
# 3                         60              31920        127360.8       3.99
# 4                         60              38000        121600.0       3.20
#
#   Unit Price             Manufacturing Site First Line Designation  \
# 0       0.97     Ranbaxy Fine Chemicals LTD                    Yes
# 1       0.03      Aurobindo Unit III, India                    Yes
# 2       0.80  ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3       0.07  Ranbaxy, Paonta Shahib, India                    Yes
# 4       0.05      Aurobindo Unit III, India                    Yes
#
#   Weight (Kilograms) Freight Cost (USD) Line Item Insurance (USD)
# 0                 13             780.34                       NaN
# 1                358             4521.5                       NaN
# 2                171            1653.78                       NaN
# 3               1855           16007.06                       NaN
# 4               7590           45450.08                       NaN
#
# [5 rows x 32 columns]

# %%
df.sample(10)
# Out:
#           ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 2556   12766   106-HT-T01  Pre-PQ Process      SO-1287     DN-614
# 3522   28001   133-NG-T30       FPQ-10765  SCMS-162440  ASN-18173
# 4668   48517   100-ZW-T30        FPQ-5018   SCMS-65350   ASN-6754
# 4357   42980   117-ET-T30        FPQ-9210  SCMS-134760  ASN-14231
# 8370   84441   106-HT-T30       FPQ-15610     SO-50590    DN-4090
# 7553   83454   114-UG-T30        FPQ-5275     SO-36230    DN-1987
# 9707   86029   109-TZ-T30       FPQ-12587     SO-45997    DN-3477
# 6817   82522   104-CI-T30        FPQ-9136     SO-41371    DN-2893
# 7367   83198   151-NG-T30       FPQ-12248     SO-45662    DN-3476
# 10007  86406   111-MZ-T30        FPQ-7053     SO-38691    DN-2330
#
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 2556           Haiti   PMO - US     From RDC   N/A - From RDC           Air
# 3522         Nigeria   PMO - US  Direct Drop              EXW           Air
# 4668        Zimbabwe   PMO - US  Direct Drop              EXW           Air
# 4357        Ethiopia   PMO - US  Direct Drop              EXW           Air
# 8370           Haiti   PMO - US     From RDC   N/A - From RDC           Air
# 7553          Uganda   PMO - US     From RDC   N/A - From RDC           Air
# 9707        Tanzania   PMO - US     From RDC   N/A - From RDC         Truck
# 6817   Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 7367         Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10007     Mozambique   PMO - US     From RDC   N/A - From RDC         Truck
#
#        ... Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 2556   ...                         60              32129        97672.16
# 3522   ...                        100               2853       253917.00
# 4668   ...                        100               1845       132840.00
# 4357   ...                          1                924        22638.00
# 8370   ...                        120               2000        37800.00
# 7553   ...                         30                650         7637.50
# 9707   ...                         60               9312        21417.60
# 6817   ...                        120                503        13430.10
# 7367   ...                         60             100000       858000.00
# 10007  ...                        240               1822         3680.44
#
#       Pack Price Unit Price                     Manufacturing Site  \
# 2556        3.04       0.05          Ranbaxy, Paonta Shahib, India
# 3522       89.00       0.89                Alere Medical Co., Ltd.
# 4668       72.00       0.72                        Inverness Japan
# 4357       24.50      24.50  KHB Test Kit Facility, Shanghai China
# 8370       18.90       0.16            ABBVIE Ludwigshafen Germany
# 7553       11.75       0.39         Mylan (formerly Matrix) Nashik
# 9707        2.30       0.04                      Cipla, Goa, India
# 6817       26.70       0.22              Aurobindo Unit III, India
# 7367        8.58       0.14                      Cipla, Goa, India
# 10007       2.02       0.01              Aurobindo Unit III, India
#
#       First Line Designation      Weight (Kilograms)  \
# 2556                      No  See DN-614 (ID#:11219)
# 3522                     Yes                    1294
# 4668                     Yes                    1000
# 4357                     Yes                     656
# 8370                     Yes                     457
# 7553                     Yes                      61
# 9707                     Yes                    1221
# 6817                     Yes                     123
# 7367                     Yes                   38992
# 10007                    Yes                     707
#
#                        Freight Cost (USD) Line Item Insurance (USD)
# 2556               See DN-614 (ID#:11219)                    156.28
# 3522   Freight Included in Commodity Cost                    355.99
# 4668                             18841.09                    286.40
# 4357                              6488.44                     31.74
# 8370                               5413.7                     44.49
# 7553                               536.02                     16.47
# 9707                               4847.8                     26.49
# 6817                              1783.64                     18.83
# 7367                             49199.75                   1061.35
# 10007                              826.26                      6.07
#
# [10 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# ID                                0
# Project Code                      0
# PQ #                              0
# PO / SO #                         0
# ASN/DN #                          0
# Country                           0
# Managed By                        0
# Fulfill Via                       0
# Vendor INCO Term                  0
# Shipment Mode                     0
# PQ First Sent to Client Date      0
# PO Sent to Vendor Date            0
# Scheduled Delivery Date           0
# Delivered to Client Date          0
# Delivery Recorded Date            0
# Product Group                     0
# Sub Classification                0
# Vendor                            0
# Item Description                  0
# Molecule/Test Type                0
# Brand                             0
# Dosage Form                       0
# Unit of Measure (Per Pack)        0
# Line Item Quantity                0
# Line Item Value                   0
# Pack Price                        0
# Unit Price                        0
# Manufacturing Site                0
# First Line Designation            0
# Weight (Kilograms)                0
# Freight Cost (USD)                0
# Line Item Insurance (USD)       287
# dtype: int64

# %%
df['Shipment Mode'] = df['Shipment Mode'].fillna(method='bfill')
# Out:
# <ipython-input-6-66314a1fa45f>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Shipment Mode'] = df['Shipment Mode'].fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                      0
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# Line Item Value                    0
# Pack Price                         0
# Unit Price                         0
# Manufacturing Site                 0
# First Line Designation             0
# Weight (Kilograms)                 0
# Freight Cost (USD)                 0
# Line Item Insurance (USD)        287
# dtype: int64

# %%
df['Line Item Insurance (USD)'].unique()
# Out:
# array([    nan,  192.  ,  128.  , ..., 5284.04,  134.03,   85.82])

# %%
df.drop('Dosage', axis=1, inplace=True)

# %%
df['Freight Cost (USD)'].unique()
# Out:
# array(['780.34', '4521.5', '1653.78', ..., '26180', '3410',
#        'See DN-4282 (ID#:83919)'], dtype=object)

# %%
df['Line Item Insurance (USD)'].fillna(0).mean()
df['Line Item Insurance (USD)'] = df['Line Item Insurance (USD)'].fillna(0)

# %%
df.isnull().sum()
# Out:
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# Pack Price                      0
# Unit Price                      0
# Manufacturing Site              0
# First Line Designation          0
# Weight (Kilograms)              0
# Freight Cost (USD)              0
# Line Item Insurance (USD)       0
# dtype: int64

# %%
df.loc[df['ASN/DN #'] == 'DN-614']
# Out:
#          ID Project Code            PQ # PO / SO # ASN/DN # Country  \
# 1497  11219   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 1499  11223   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2139  12151   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2556  12766   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
#
#      Managed By Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 1497   PMO - US    From RDC   N/A - From RDC           Air  ...
# 1499   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2139   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2556   PMO - US    From RDC   N/A - From RDC           Air  ...
#
#      Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 1497                        240               3000         6450.00       2.15
# 1499                         60                120          180.00       1.50
# 2139                        200                300          420.00       1.40
# 2556                         60              32129        97672.16       3.04
#
#      Unit Price             Manufacturing Site First Line Designation  \
# 1497       0.01      Aurobindo Unit III, India                    Yes
# 1499       0.02      Aurobindo Unit III, India                     No
# 2139       0.01      Aurobindo Unit III, India                     No
# 2556       0.05  Ranbaxy, Paonta Shahib, India                     No
#
#           Weight (Kilograms)      Freight Cost (USD) Line Item Insurance (USD)
# 1497                    2584                 26877.3                     10.32
# 1499  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                      0.29
# 2139  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                      0.67
# 2556  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                    156.28
#
# [4 rows x 32 columns]

# %%
df.loc[df['Freight Cost (USD)'] =='See DN-614 (ID#:11219)' ]
# Out:
#          ID Project Code            PQ # PO / SO # ASN/DN # Country  \
# 1499  11223   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2139  12151   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2556  12766   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
#
#      Managed By Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 1499   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2139   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2556   PMO - US    From RDC   N/A - From RDC           Air  ...
#
#      Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 1499                         60                120          180.00       1.50
# 2139                        200                300          420.00       1.40
# 2556                         60              32129        97672.16       3.04
#
#      Unit Price             Manufacturing Site First Line Designation  \
# 1499       0.02      Aurobindo Unit III, India                     No
# 2139       0.01      Aurobindo Unit III, India                     No
# 2556       0.05  Ranbaxy, Paonta Shahib, India                     No
#
#           Weight (Kilograms)      Freight Cost (USD) Line Item Insurance (USD)
# 1499  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                      0.29
# 2139  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                      0.67
# 2556  See DN-614 (ID#:11219)  See DN-614 (ID#:11219)                    156.28
#
# [3 rows x 32 columns]

# %%
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['See DN-614 (ID#:11219)', 'See DN-614'], 26877.3)

# %%
df.loc[df['Freight Cost (USD)'] =='See DN-614 (ID#:11219)' ]
# Out:
# Empty DataFrame
# Columns: [ID, Project Code, PQ #, PO / SO #, ASN/DN #, Country, Managed By, Fulfill Via, Vendor INCO Term, Shipment Mode, PQ First Sent to Client Date, PO Sent to Vendor Date, Scheduled Delivery Date, Delivered to Client Date, Delivery Recorded Date, Product Group, Sub Classification, Vendor, Item Description, Molecule/Test Type, Brand, Dosage Form, Unit of Measure (Per Pack), Line Item Quantity, Line Item Value, Pack Price, Unit Price, Manufacturing Site, First Line Designation, Weight (Kilograms), Freight Cost (USD), Line Item Insurance (USD)]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.sample(10)
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 2881  16379   116-ZA-T30       FPQ-14942  SCMS-259077  ASN-33478
# 5122  56844   110-ZM-T30        FPQ-6263   SCMS-87290   ASN-8999
# 9554  85853   110-ZM-T30        FPQ-8476     SO-40955    DN-2624
# 1939  11862   131-NG-T01  Pre-PQ Process      SO-2578     DN-739
# 6130  74288   108-VN-T30       FPQ-14516  SCMS-251680  ASN-29386
# 437    4259   116-ZA-T01  Pre-PQ Process   SCMS-16600   ASN-1520
# 4899  52636   106-HT-T30       FPQ-12590  SCMS-210470  ASN-24370
# 2736  13899   116-ZA-T30       FPQ-14942  SCMS-259071  ASN-29597
# 8322  84367   107-RW-T30       FPQ-12766     SO-46501    DN-3699
# 1323  10962   125-HT-T01  Pre-PQ Process      SO-1291     DN-686
#
#            Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 2881  South Africa   PMO - US  Direct Drop              DDP         Truck
# 5122        Zambia   PMO - US  Direct Drop              EXW           Air
# 9554        Zambia   PMO - US     From RDC   N/A - From RDC         Truck
# 1939       Nigeria   PMO - US     From RDC   N/A - From RDC           Air
# 6130       Vietnam   PMO - US  Direct Drop              EXW           Air
# 437   South Africa   PMO - US  Direct Drop              DDP           Air
# 4899         Haiti   PMO - US  Direct Drop              EXW         Ocean
# 2736  South Africa   PMO - US  Direct Drop              DDP         Truck
# 8322        Rwanda   PMO - US     From RDC   N/A - From RDC         Truck
# 1323         Haiti   PMO - US     From RDC   N/A - From RDC           Air
#
#       ... Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 2881  ...                        120                 27          742.84
# 5122  ...                        100               2041       163280.00
# 9554  ...                         60                887         7096.00
# 1939  ...                         30               3359        88173.75
# 6130  ...                         30              10000        35000.00
# 437   ...                        240                300         2049.00
# 4899  ...                        240               2040         3080.40
# 2736  ...                         90                 16          272.70
# 8322  ...                         30              53705       249191.20
# 1323  ...                        100                 25         1800.00
#
#      Pack Price Unit Price             Manufacturing Site  \
# 2881      27.51       0.23      Janssen-Cilag, Latina, IT
# 5122      80.00       0.80                Inverness Japan
# 9554       8.00       0.13         Aurobindo Unit VII, IN
# 1939      26.25       0.88  Aspen-OSD, Port Elizabeth, SA
# 6130       3.50       0.12   Hetero Unit III Hyderabad IN
# 437        6.83       0.03       GSK Mississauga (Canada)
# 4899       1.51       0.01      Aurobindo Unit III, India
# 2736      17.04       0.19      Aurobindo Unit III, India
# 8322       4.64       0.15   Hetero Unit III Hyderabad IN
# 1323      72.00       0.72                Inverness Japan
#
#      First Line Designation          Weight (Kilograms)  \
# 2881                    Yes  Weight Captured Separately
# 5122                    Yes                         989
# 9554                     No     See DN-2624 (ID#:83584)
# 1939                    Yes                         300
# 6130                     No   See ASN-29386 (ID#:42295)
# 437                      No  Weight Captured Separately
# 4899                    Yes                         820
# 2736                    Yes  Weight Captured Separately
# 8322                    Yes                        5565
# 1323                     No      See DN-686 (ID#:10691)
#
#                       Freight Cost (USD) Line Item Insurance (USD)
# 2881  Freight Included in Commodity Cost                      0.76
# 5122                            16654.29                    352.03
# 9554             See DN-2624 (ID#:83584)                     11.71
# 1939                                2204                    141.08
# 6130           See ASN-29386 (ID#:42295)                     35.98
# 437   Freight Included in Commodity Cost                      3.28
# 4899                             2214.69                      3.81
# 2736  Freight Included in Commodity Cost                      0.28
# 8322                             34837.8                    308.25
# 1323              See DN-686 (ID#:10691)                      2.88
#
# [10 rows x 32 columns]

# %%
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['Freight Included in Commodity Cost'],0)
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['Invoiced Separately	'],0)#Invoiced Separately

# %%
df.sample(10)
# Out:
#           ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 9326   85594   104-CI-T30       FPQ-15259     SO-50100    DN-4255
# 8026   84032   104-CI-T30        FPQ-5623     SO-36890    DN-1984
# 10059  86461   114-UG-T30        FPQ-9321     SO-41521    DN-2596
# 7918   83901   111-MZ-T30       FPQ-15195     SO-50140    DN-4191
# 2230   12267   117-ET-T01  Pre-PQ Process     SO-22190    DN-1091
# 846     8802   109-TZ-T01  Pre-PQ Process   SCMS-34430   ASN-3699
# 2795   14811   107-RW-T30       FPQ-13874  SCMS-232310  ASN-25543
# 10128  86532   151-NG-T30        FPQ-9968     SO-42680    DN-2947
# 8169   84184   113-ZW-T30        FPQ-8464     SO-40892    DN-2802
# 2883   16398   107-RW-T30        FPQ-6341   SCMS-84930  ASN-12601
#
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 9326   Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC         Truck
# 8026   Côte d'Ivoire   PMO - US     From RDC   N/A - From RDC           Air
# 10059         Uganda   PMO - US     From RDC   N/A - From RDC         Truck
# 7918      Mozambique   PMO - US     From RDC   N/A - From RDC         Truck
# 2230        Ethiopia   PMO - US     From RDC   N/A - From RDC           Air
# 846         Tanzania   PMO - US  Direct Drop              EXW           Air
# 2795          Rwanda   PMO - US  Direct Drop              EXW           Air
# 10128        Nigeria   PMO - US     From RDC   N/A - From RDC           Air
# 8169        Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
# 2883          Rwanda   PMO - US  Direct Drop              EXW         Ocean
#
#        ... Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 9326   ...                         30              45204       141036.48
# 8026   ...                         30               2436         5456.64
# 10059  ...                         30               1150         4738.00
# 7918   ...                         30             122449      1175510.40
# 2230   ...                         60               5000        43800.00
# 846    ...                         20                839        26848.00
# 2795   ...                          1               4068        99666.00
# 10128  ...                         60             138508      1332446.96
# 8169   ...                         60               4451        13130.45
# 2883   ...                        120              23240       776216.00
#
#       Pack Price Unit Price                     Manufacturing Site  \
# 9326        3.12       0.10             Strides, Bangalore, India.
# 8026        2.24       0.07              Aurobindo Unit III, India
# 10059       4.12       0.14             Strides, Bangalore, India.
# 7918        9.60       0.32         Mylan (formerly Matrix) Nashik
# 2230        8.76       0.15         Mylan (formerly Matrix) Nashik
# 846        32.00       1.60                   Trinity Biotech, Plc
# 2795       24.50      24.50  KHB Test Kit Facility, Shanghai China
# 10128       9.62       0.16         Mylan (formerly Matrix) Nashik
# 8169        2.95       0.05             Strides, Bangalore, India.
# 2883       33.40       0.28          Cipla Ltd A-42 MIDC Mahar. IN
#
#       First Line Designation       Weight (Kilograms)  \
# 9326                      No  See DN-4255 (ID#:83911)
# 8026                      No  See DN-1984 (ID#:83453)
# 10059                    Yes                       70
# 7918                      No  See DN-4191 (ID#:83900)
# 2230                     Yes                      403
# 846                      Yes                      277
# 2795                     Yes                     2712
# 10128                     No  See DN-2947 (ID#:83642)
# 8169                     Yes                      228
# 2883                     Yes                     6853
#
#             Freight Cost (USD) Line Item Insurance (USD)
# 9326   See DN-4255 (ID#:83911)                    166.00
# 8026   See DN-1984 (ID#:83453)                     11.76
# 10059                   1494.6                      6.64
# 7918   See DN-4191 (ID#:83900)                   1383.58
# 2230                   1719.65                     85.85
# 846                    3146.63                     52.62
# 2795                  37680.04                    102.46
# 10128  See DN-2947 (ID#:83642)                   1868.09
# 8169                   7423.38                     21.67
# 2883                  81246.12                   1673.52
#
# [10 rows x 32 columns]

# %%
df['Weight (Kilograms)'] = df['Weight (Kilograms)'].replace(['See DN-614 (ID#:11219)', 'See DN-614'], 2584)

# %%
df.sample(10)
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 999   10367   116-ZA-T01  Pre-PQ Process   SCMS-49550   ASN-4610
# 1079  10637   117-ET-T01  Pre-PQ Process      SO-1342     DN-459
# 4267  41301   116-ZA-T30       FPQ-14942  SCMS-259073  ASN-30673
# 4099  38418   116-ZA-T30       FPQ-14942  SCMS-259075  ASN-32122
# 7251  83062   900-UG-T30       FPQ-10048     SO-42581    DN-2782
# 4402  43834   901-NA-T30       FPQ-14728  SCMS-252630  ASN-29184
# 1555  11294   106-HT-T01  Pre-PQ Process     SO-23750    DN-1100
# 7253  83064   151-NG-T30        FPQ-9432     SO-42930    DN-2791
# 4192  40152   116-ZA-T30       FPQ-14942  SCMS-259071  ASN-29597
# 8572  84678   113-ZW-T30        FPQ-7052     SO-38513    DN-2410
#
#            Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 999   South Africa   PMO - US  Direct Drop              DDP         Truck
# 1079      Ethiopia   PMO - US     From RDC   N/A - From RDC           Air
# 4267  South Africa   PMO - US  Direct Drop              DDP         Truck
# 4099  South Africa   PMO - US  Direct Drop              DDP         Truck
# 7251        Uganda   PMO - US     From RDC   N/A - From RDC           Air
# 4402       Namibia   PMO - US  Direct Drop              EXW           Air
# 1555         Haiti   PMO - US     From RDC   N/A - From RDC           Air
# 7253       Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
# 4192  South Africa   PMO - US  Direct Drop              DDP         Truck
# 8572      Zimbabwe   PMO - US     From RDC   N/A - From RDC         Truck
#
#       ... Unit of Measure (Per Pack) Line Item Quantity Line Item Value  \
# 999   ...                         60               7000        37520.00
# 1079  ...                        200               7294        10211.60
# 4267  ...                        120                  2           51.19
# 4099  ...                         60                 56          369.98
# 7251  ...                        120               5000       148400.00
# 4402  ...                         30              29160       306180.00
# 1555  ...                         90                210         3204.60
# 7253  ...                         60               1048         8384.00
# 4192  ...                        240                  8          141.69
# 8572  ...                         60                 76          224.20
#
#      Pack Price Unit Price                    Manufacturing Site  \
# 999        5.36       0.09  GSK Cape Town Factory (South Africa)
# 1079       1.40       0.01             Aurobindo Unit III, India
# 4267      25.60       0.21             Janssen-Cilag, Latina, IT
# 4099       6.61       0.11             Aurobindo Unit III, India
# 7251      29.68       0.25             Aurobindo Unit III, India
# 4402      10.50       0.35            Mylan,  H-12 & H-13, India
# 1555      15.26       0.17             Aurobindo Unit III, India
# 7253       8.00       0.13                     Cipla, Goa, India
# 4192      17.71       0.07             Aurobindo Unit III, India
# 8572       2.95       0.05                     Cipla, Goa, India
#
#      First Line Designation          Weight (Kilograms)  \
# 999                     Yes  Weight Captured Separately
# 1079                    Yes                         753
# 4267                    Yes  Weight Captured Separately
# 4099                     No  Weight Captured Separately
# 7251                    Yes                        1199
# 4402                    Yes                        3402
# 1555                     No     See DN-1100 (ID#:11005)
# 7253                    Yes                        4809
# 4192                     No  Weight Captured Separately
# 8572                    Yes                         248
#
#            Freight Cost (USD) Line Item Insurance (USD)
# 999                         0                     73.54
# 1079                     8004                     16.34
# 4267                        0                      0.05
# 4099                        0                      0.38
# 7251                     7070                    208.06
# 4402                  17118.8                    314.75
# 1555  See DN-1100 (ID#:11005)                      6.28
# 7253                 18461.23                     11.75
# 4192                        0                      0.15
# 8572                   481.71                      0.37
#
# [10 rows x 32 columns]
