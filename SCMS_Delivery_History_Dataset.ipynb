# %% [markdown]
# <a href="https://colab.research.google.com/github/itarasingh/SCMS_Delivery_History_Dataset.csv/blob/main/SCMS_Delivery_History_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/itarasingh/SCMS_Delivery_History_Dataset.csv/refs/heads/main/SCMS_Delivery_History_Dataset.csv')

# %%
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
df.sample(10)
# Out:
#          ID Project Code       PQ #    PO / SO #   ASN/DN #        Country  \
# 7182  82988   104-CI-T30   FPQ-8295     SO-40810    DN-2418  Côte d'Ivoire
# 9150  85348   105-GY-T30  FPQ-11546     SO-44500    DN-3099         Guyana
# 5496  63555   104-CI-T30  FPQ-10636  SCMS-162550  ASN-18558  Côte d'Ivoire
# 8704  84812   113-ZW-T30  FPQ-11002     SO-43710    DN-3131       Zimbabwe
# 6497  80918   116-ZA-T30   FPQ-3560   SCMS-49642   ASN-5244   South Africa
# 5766  67776   108-VN-T30   FPQ-4662   SCMS-58610   ASN-5841        Vietnam
# 4196  40255   108-VN-T30  FPQ-13034  SCMS-210040  ASN-24697        Vietnam
# 6544  81739   116-ZA-T30  FPQ-14942  SCMS-259079  ASN-33852   South Africa
# 5884  70041   107-RW-T30  FPQ-14813  SCMS-261780  ASN-32156         Rwanda
# 6440  79841   107-RW-T30   FPQ-8741  SCMS-129510  ASN-15328         Rwanda
#
#      Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 7182   PMO - US     From RDC   N/A - From RDC         Truck  ...
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
df['Shipment Mode'] = df['Shipment Mode'].fillna(method='bfill')
# Out:
# <ipython-input-6-66314a1fa45f>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Shipment Mode'] = df['Shipment Mode'].fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                      0
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
df['Line Item Insurance (USD)'].unique()
# Out:
# array([    nan,  192.  ,  128.  , ..., 5284.04,  134.03,   85.82])

# %%
df.drop('Dosage', axis=1, inplace=True)

# %%
df['Freight Cost (USD)'].unique()
# Out:
# array(['780.34', '4521.5', '1653.78', ..., '26180', '3410',
#        'See DN-4282 (ID#:83919)'], dtype=object)

# %%
df['Line Item Insurance (USD)'].fillna(0).mean()
df['Line Item Insurance (USD)'] = df['Line Item Insurance (USD)'].fillna(0)

# %%
df.isnull().sum()
# Out:
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# Pack Price                      0
# Unit Price                      0
# ...

# %%
df.loc[df['ASN/DN #'] == 'DN-614']
# Out:
#          ID Project Code            PQ # PO / SO # ASN/DN # Country  \
# 1497  11219   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 1499  11223   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2139  12151   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2556  12766   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
#
#      Managed By Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 1497   PMO - US    From RDC   N/A - From RDC           Air  ...
# 1499   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2139   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2556   PMO - US    From RDC   N/A - From RDC           Air  ...
#
#      Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 1497                        240               3000         6450.00       2.15
# 1499                         60                120          180.00       1.50
# ...

# %%
df.loc[df['Freight Cost (USD)'] =='See DN-614 (ID#:11219)' ]
# Out:
#          ID Project Code            PQ # PO / SO # ASN/DN # Country  \
# 1499  11223   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2139  12151   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
# 2556  12766   106-HT-T01  Pre-PQ Process   SO-1287   DN-614   Haiti
#
#      Managed By Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 1499   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2139   PMO - US    From RDC   N/A - From RDC           Air  ...
# 2556   PMO - US    From RDC   N/A - From RDC           Air  ...
#
#      Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 1499                         60                120          180.00       1.50
# 2139                        200                300          420.00       1.40
# 2556                         60              32129        97672.16       3.04
#
#      Unit Price             Manufacturing Site First Line Designation  \
# ...

# %%
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['See DN-614 (ID#:11219)', 'See DN-614'], 26877.3)

# %%
df.loc[df['Freight Cost (USD)'] =='See DN-614 (ID#:11219)' ]
# Out:
# Empty DataFrame
# Columns: [ID, Project Code, PQ #, PO / SO #, ASN/DN #, Country, Managed By, Fulfill Via, Vendor INCO Term, Shipment Mode, PQ First Sent to Client Date, PO Sent to Vendor Date, Scheduled Delivery Date, Delivered to Client Date, Delivery Recorded Date, Product Group, Sub Classification, Vendor, Item Description, Molecule/Test Type, Brand, Dosage Form, Unit of Measure (Per Pack), Line Item Quantity, Line Item Value, Pack Price, Unit Price, Manufacturing Site, First Line Designation, Weight (Kilograms), Freight Cost (USD), Line Item Insurance (USD)]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.sample(10)
# Out:
#           ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 5815   68662   901-CM-T30       FPQ-12837  SCMS-204300  ASN-21703
# 1633   11404   110-ZM-T01  Pre-PQ Process       SO-230     DN-165
# 4646   48043   102-KE-T30        FPQ-6114   SCMS-80820   ASN-8589
# 10198  86614   104-CI-T30       FPQ-12712     SO-46300    DN-3372
# 5347   61271   114-UG-T30       FPQ-12777  SCMS-202560  ASN-22983
# 2544   12751   112-NG-T01  Pre-PQ Process       SO-567     DN-475
# 1965   11893   117-ET-T01  Pre-PQ Process      SO-1518     DN-634
# 4148   39263   108-VN-T30        FPQ-6384   SCMS-87780   ASN-9408
# 7636   83540   114-UG-T30        FPQ-7166     SO-38870    DN-2389
# 6298   77181   114-UG-T30       FPQ-11153  SCMS-171920  ASN-18279
#
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 5815        Cameroon   PMO - US  Direct Drop              EXW           Air
# 1633          Zambia   PMO - US     From RDC   N/A - From RDC           Air
# ...

# %%
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['Freight Included in Commodity Cost'],0)
df['Freight Cost (USD)'] = df['Freight Cost (USD)'].replace(['Invoiced Separately	'],0)#Invoiced Separately

# %%
df['Weight (Kilograms)'] = df['Weight (Kilograms)'].replace(['See DN-614 (ID#:11219)', 'See DN-614'], 2584)

# %%
df.sample(10)
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 9009  85194   111-MZ-T30        FPQ-7053     SO-38632    DN-2284
# 3468  26996   116-ZA-T30       FPQ-14942  SCMS-259071  ASN-29597
# 1668  11480   104-CI-T01  Pre-PQ Process      SO-1546     DN-609
# 9619  85920   111-MZ-T30       FPQ-10211     SO-42870    DN-2966
# 267    2571   119-NA-T01  Pre-PQ Process   SCMS-45620   ASN-4511
# 4662  48319   116-ZA-T30       FPQ-13214  SCMS-215410  ASN-23875
# 3752  32279   116-ZA-T30        FPQ-3560   SCMS-49641   ASN-5157
# 5089  56125   901-CM-T30       FPQ-12837  SCMS-204290  ASN-23425
# 5080  56005   106-HT-T30       FPQ-13797  SCMS-233970  ASN-27794
# 4998  54579   116-ZA-T30       FPQ-11828  SCMS-183950  ASN-19166
#
#             Country                 Managed By  Fulfill Via Vendor INCO Term  \
# 9009     Mozambique                   PMO - US     From RDC   N/A - From RDC
# 3468   South Africa                   PMO - US  Direct Drop              DDP
# ...

# %%
df.drop(['Weight (Kilograms)','Freight Cost (USD)'], axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#           ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 7742   83648   151-NG-T30       FPQ-10477     SO-43043    DN-2995
# 920     9499   107-RW-T01  Pre-PQ Process   SCMS-14730   ASN-1067
# 6438   79810   101-CD-T30       FPQ-14654  SCMS-253260  ASN-28279
# 6557   81961   116-ZA-T30       FPQ-11828  SCMS-183950  ASN-19166
# 601     5976   117-ET-T01  Pre-PQ Process   SCMS-28720   ASN-2579
# 5015   54840   133-NG-T30       FPQ-10765  SCMS-162440  ASN-17524
# 3848   33969   109-TZ-T30        FPQ-5446   SCMS-71300   ASN-7529
# 10083  86486   151-NG-T30        FPQ-9432     SO-42335    DN-2709
# 1598   11351   111-MZ-T01  Pre-PQ Process     SO-32560    DN-1395
# 10193  86607   111-MZ-T30       FPQ-11884     SO-44870    DN-3339
#
#             Country                 Managed By  Fulfill Via Vendor INCO Term  \
# 7742        Nigeria                   PMO - US     From RDC   N/A - From RDC
# 920          Rwanda                   PMO - US  Direct Drop              CIP
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Shipment Mode', data=df)
plt.title('Shipment Mode Visualization')
plt.xlabel('Shipment Mode')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
country_counts = df['Country'].value_counts()

plt.figure(figsize=(10, 8))
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Shipments by Country')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_sites = df['Manufacturing Site'].value_counts().nlargest(5)
sns.barplot(x=top_sites.index, y=top_sites.values)
plt.title('Top 5 Manufacturing Sites')
plt.xlabel('Manufacturing Site')
plt.ylabel('Number of Shipments')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='ID', y='Country', data=df)
plt.title('ID vs Country Scatter Plot')
plt.xlabel('ID')
plt.ylabel('Country')
plt.show()
